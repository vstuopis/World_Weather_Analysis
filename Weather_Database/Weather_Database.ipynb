# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 780

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
          
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
 #   except:
 #       print("City not found. Skipping...")
    except Exception as e:
        print(e) 
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | san jose
# Processing Record 2 of Set 1 | saint austell
# Processing Record 3 of Set 1 | illoqqortoormiut
# 'coord'
# Processing Record 4 of Set 1 | falealupo
# 'coord'
# Processing Record 5 of Set 1 | provideniya
# Processing Record 6 of Set 1 | barrow
# Processing Record 7 of Set 1 | altamira
# Processing Record 8 of Set 1 | beringovskiy
# Processing Record 9 of Set 1 | arraial do cabo
# Processing Record 10 of Set 1 | esperance
# Processing Record 11 of Set 1 | naron
# Processing Record 12 of Set 1 | saldanha
# Processing Record 13 of Set 1 | hithadhoo
# Processing Record 14 of Set 1 | pevek
# Processing Record 15 of Set 1 | nikolskoye
# Processing Record 16 of Set 1 | half moon bay
# Processing Record 17 of Set 1 | castro
# Processing Record 18 of Set 1 | mariinsk
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | victoria
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | fakel
# Processing Record 23 of Set 1 | umzimvubu
# 'coord'
# Processing Record 24 of Set 1 | ketchikan
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | sumbe
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | inirida
# Processing Record 30 of Set 1 | saint-philippe
# Processing Record 31 of Set 1 | santa vitoria do palmar
# Processing Record 32 of Set 1 | komsomolskiy
# Processing Record 33 of Set 1 | juquia
# Processing Record 34 of Set 1 | lebu
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | blankenberge
# Processing Record 37 of Set 1 | mrirt
# 'coord'
# Processing Record 38 of Set 1 | chingirlau
# Processing Record 39 of Set 1 | mayo
# Processing Record 40 of Set 1 | magadan
# Processing Record 41 of Set 1 | mys shmidta
# 'coord'
# Processing Record 42 of Set 1 | puerto escondido
# Processing Record 43 of Set 1 | louisbourg
# 'coord'
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | winkler
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | tateyama
# Processing Record 48 of Set 1 | avarua
# Processing Record 49 of Set 1 | mount isa
# Processing Record 50 of Set 1 | georgetown
# Processing Record 1 of Set 2 | vila
# Processing Record 2 of Set 2 | mar del plata
# Processing Record 3 of Set 2 | esso
# Processing Record 4 of Set 2 | amapa
# Processing Record 5 of Set 2 | hobart
# Processing Record 6 of Set 2 | aksarka
# Processing Record 7 of Set 2 | mandalgovi
# Processing Record 8 of Set 2 | rikitea
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | busselton
# Processing Record 11 of Set 2 | kavieng
# Processing Record 12 of Set 2 | vaitupu
# 'coord'
# Processing Record 13 of Set 2 | baiyin
# Processing Record 14 of Set 2 | yumen
# Processing Record 15 of Set 2 | isangel
# Processing Record 16 of Set 2 | cam ranh
# Processing Record 17 of Set 2 | yerbogachen
# Processing Record 18 of Set 2 | sao filipe
# Processing Record 19 of Set 2 | dikson
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | new norfolk
# Processing Record 22 of Set 2 | hami
# Processing Record 23 of Set 2 | broome
# Processing Record 24 of Set 2 | goure
# Processing Record 25 of Set 2 | rorvik
# Processing Record 26 of Set 2 | bela
# Processing Record 27 of Set 2 | katsuura
# Processing Record 28 of Set 2 | naguabo
# Processing Record 29 of Set 2 | souillac
# Processing Record 30 of Set 2 | kautokeino
# Processing Record 31 of Set 2 | mega
# Processing Record 32 of Set 2 | carnarvon
# Processing Record 33 of Set 2 | qaanaaq
# Processing Record 34 of Set 2 | kahului
# Processing Record 35 of Set 2 | narsaq
# Processing Record 36 of Set 2 | mataura
# Processing Record 37 of Set 2 | grand gaube
# Processing Record 38 of Set 2 | sestri levante
# Processing Record 39 of Set 2 | bako
# Processing Record 40 of Set 2 | itupiranga
# Processing Record 41 of Set 2 | muros
# Processing Record 42 of Set 2 | canico
# Processing Record 43 of Set 2 | tuktoyaktuk
# Processing Record 44 of Set 2 | punta arenas
# Processing Record 45 of Set 2 | los llanos de aridane
# Processing Record 46 of Set 2 | bathsheba
# Processing Record 47 of Set 2 | vardo
# Processing Record 48 of Set 2 | thompson
# Processing Record 49 of Set 2 | aripuana
# Processing Record 50 of Set 2 | falam
# Processing Record 1 of Set 3 | hermanus
# Processing Record 2 of Set 3 | chulakivka
# Processing Record 3 of Set 3 | taolanaro
# 'coord'
# Processing Record 4 of Set 3 | port keats
# Processing Record 5 of Set 3 | yokosuka
# Processing Record 6 of Set 3 | leningradskiy
# Processing Record 7 of Set 3 | juneau
# Processing Record 8 of Set 3 | saint-augustin
# Processing Record 9 of Set 3 | camopi
# Processing Record 10 of Set 3 | tumannyy
# 'coord'
# Processing Record 11 of Set 3 | havre-saint-pierre
# Processing Record 12 of Set 3 | ponazyrevo
# Processing Record 13 of Set 3 | lorengau
# Processing Record 14 of Set 3 | longyearbyen
# Processing Record 15 of Set 3 | oriximina
# Processing Record 16 of Set 3 | kodiak
# Processing Record 17 of Set 3 | faanui
# Processing Record 18 of Set 3 | bowen
# Processing Record 19 of Set 3 | kodinsk
# Processing Record 20 of Set 3 | trofors
# Processing Record 21 of Set 3 | batagay
# Processing Record 22 of Set 3 | hervey bay
# Processing Record 23 of Set 3 | tuatapere
# Processing Record 24 of Set 3 | saint-joseph
# Processing Record 25 of Set 3 | saleaula
# 'coord'
# Processing Record 26 of Set 3 | san quintin
# Processing Record 27 of Set 3 | marawi
# Processing Record 28 of Set 3 | avera
# Processing Record 29 of Set 3 | thyboron
# Processing Record 30 of Set 3 | ponta do sol
# Processing Record 31 of Set 3 | shahrud
# Processing Record 32 of Set 3 | port blair
# Processing Record 33 of Set 3 | aklavik
# Processing Record 34 of Set 3 | airai
# Processing Record 35 of Set 3 | coihaique
# Processing Record 36 of Set 3 | lazaro cardenas
# Processing Record 37 of Set 3 | nanortalik
# Processing Record 38 of Set 3 | anadyr
# Processing Record 39 of Set 3 | palmer
# Processing Record 40 of Set 3 | farap
# Processing Record 41 of Set 3 | severo-kurilsk
# Processing Record 42 of Set 3 | naze
# Processing Record 43 of Set 3 | barabai
# Processing Record 44 of Set 3 | laguna
# Processing Record 45 of Set 3 | ixtapa
# Processing Record 46 of Set 3 | marcona
# 'coord'
# Processing Record 47 of Set 3 | aitape
# Processing Record 48 of Set 3 | belushya guba
# 'coord'
# Processing Record 49 of Set 3 | ofunato
# Processing Record 50 of Set 3 | touros
# Processing Record 1 of Set 4 | atuona
# Processing Record 2 of Set 4 | talnakh
# Processing Record 3 of Set 4 | cape town
# Processing Record 4 of Set 4 | sitka
# Processing Record 5 of Set 4 | pisco
# Processing Record 6 of Set 4 | axim
# Processing Record 7 of Set 4 | khatanga
# Processing Record 8 of Set 4 | sao joao da barra
# Processing Record 9 of Set 4 | baisha
# Processing Record 10 of Set 4 | christchurch
# Processing Record 11 of Set 4 | caineni
# 'coord'
# Processing Record 12 of Set 4 | sigli
# Processing Record 13 of Set 4 | torbay
# Processing Record 14 of Set 4 | bolungarvik
# 'coord'
# Processing Record 15 of Set 4 | namibe
# Processing Record 16 of Set 4 | vila franca do campo
# Processing Record 17 of Set 4 | vao
# Processing Record 18 of Set 4 | kaitangata
# Processing Record 19 of Set 4 | puerto ayora
# Processing Record 20 of Set 4 | vanavara
# Processing Record 21 of Set 4 | roma
# Processing Record 22 of Set 4 | attawapiskat
# 'coord'
# Processing Record 23 of Set 4 | mount gambier
# Processing Record 24 of Set 4 | rawson
# Processing Record 25 of Set 4 | seguela
# Processing Record 26 of Set 4 | myitkyina
# Processing Record 27 of Set 4 | wageningen
# Processing Record 28 of Set 4 | iqaluit
# Processing Record 29 of Set 4 | yellowknife
# Processing Record 30 of Set 4 | paamiut
# Processing Record 31 of Set 4 | mandera
# Processing Record 32 of Set 4 | havoysund
# Processing Record 33 of Set 4 | bereda
# Processing Record 34 of Set 4 | sola
# Processing Record 35 of Set 4 | arman
# Processing Record 36 of Set 4 | bababe
# 'coord'
# Processing Record 37 of Set 4 | ilulissat
# Processing Record 38 of Set 4 | dubenskiy
# 'coord'
# Processing Record 39 of Set 4 | esmeraldas
# Processing Record 40 of Set 4 | saskylakh
# Processing Record 41 of Set 4 | seoul
# Processing Record 42 of Set 4 | kobe
# Processing Record 43 of Set 4 | capelinha
# Processing Record 44 of Set 4 | itarema
# Processing Record 45 of Set 4 | port elizabeth
# Processing Record 46 of Set 4 | klaksvik
# Processing Record 47 of Set 4 | nome
# Processing Record 48 of Set 4 | saint-pierre
# Processing Record 49 of Set 4 | westport
# Processing Record 50 of Set 4 | toliary
# 'coord'
# Processing Record 1 of Set 5 | vostok
# Processing Record 2 of Set 5 | pinawa
# Processing Record 3 of Set 5 | sharjah
# Processing Record 4 of Set 5 | ahipara
# Processing Record 5 of Set 5 | gorin
# Processing Record 6 of Set 5 | eureka
# Processing Record 7 of Set 5 | tigre
# Processing Record 8 of Set 5 | awjilah
# Processing Record 9 of Set 5 | oranjemund
# Processing Record 10 of Set 5 | mahajanga
# Processing Record 11 of Set 5 | bethel
# Processing Record 12 of Set 5 | tual
# Processing Record 13 of Set 5 | great yarmouth
# Processing Record 14 of Set 5 | maryanovka
# 'coord'
# Processing Record 15 of Set 5 | cockburn town
# Processing Record 16 of Set 5 | sentyabrskiy
# 'coord'
# Processing Record 17 of Set 5 | segou
# Processing Record 18 of Set 5 | fort dodge
# Processing Record 19 of Set 5 | halalo
# 'coord'
# Processing Record 20 of Set 5 | aktas
# Processing Record 21 of Set 5 | zhezkazgan
# Processing Record 22 of Set 5 | narasannapeta
# Processing Record 23 of Set 5 | saint george
# Processing Record 24 of Set 5 | gogrial
# Processing Record 25 of Set 5 | san carlos de bariloche
# Processing Record 26 of Set 5 | college
# Processing Record 27 of Set 5 | codrington
# Processing Record 28 of Set 5 | ust-kulom
# Processing Record 29 of Set 5 | salaga
# Processing Record 30 of Set 5 | lagoa
# Processing Record 31 of Set 5 | herzberg
# Processing Record 32 of Set 5 | norman wells
# Processing Record 33 of Set 5 | luga
# Processing Record 34 of Set 5 | dingle
# Processing Record 35 of Set 5 | kurashiki
# Processing Record 36 of Set 5 | marsh harbour
# Processing Record 37 of Set 5 | beyneu
# Processing Record 38 of Set 5 | khandyga
# Processing Record 39 of Set 5 | safaga
# Processing Record 40 of Set 5 | singaraja
# Processing Record 41 of Set 5 | waverly
# Processing Record 42 of Set 5 | nemuro
# Processing Record 43 of Set 5 | mersin
# Processing Record 44 of Set 5 | porto seguro
# Processing Record 45 of Set 5 | porto velho
# Processing Record 46 of Set 5 | saint-denis
# Processing Record 47 of Set 5 | basco
# Processing Record 48 of Set 5 | lufilufi
# Processing Record 49 of Set 5 | bubaque
# Processing Record 50 of Set 5 | jiayuguan
# Processing Record 1 of Set 6 | santa isabel
# Processing Record 2 of Set 6 | kazachinskoye
# Processing Record 3 of Set 6 | doembang nangbuat
# Processing Record 4 of Set 6 | sug-aksy
# 'coord'
# Processing Record 5 of Set 6 | ust-omchug
# Processing Record 6 of Set 6 | haibowan
# 'coord'
# Processing Record 7 of Set 6 | camana
# Processing Record 8 of Set 6 | thinadhoo
# Processing Record 9 of Set 6 | praia da vitoria
# Processing Record 10 of Set 6 | murray
# Processing Record 11 of Set 6 | goderich
# Processing Record 12 of Set 6 | moose factory
# Processing Record 13 of Set 6 | gat
# Processing Record 14 of Set 6 | port shepstone
# Processing Record 15 of Set 6 | pital
# Processing Record 16 of Set 6 | srednekolymsk
# Processing Record 17 of Set 6 | moissac
# Processing Record 18 of Set 6 | salalah
# Processing Record 19 of Set 6 | vila velha
# Processing Record 20 of Set 6 | shieli
# Processing Record 21 of Set 6 | cherskiy
# Processing Record 22 of Set 6 | boueni
# Processing Record 23 of Set 6 | rodos
# Processing Record 24 of Set 6 | nouadhibou
# Processing Record 25 of Set 6 | bredasdorp
# Processing Record 26 of Set 6 | bulgan
# Processing Record 27 of Set 6 | saint-louis
# Processing Record 28 of Set 6 | raga
# Processing Record 29 of Set 6 | kurumkan
# Processing Record 30 of Set 6 | sotnikovskoye
# Processing Record 31 of Set 6 | krasnyy chikoy
# Processing Record 32 of Set 6 | amderma
# 'coord'
# Processing Record 33 of Set 6 | maningrida
# Processing Record 34 of Set 6 | dalen
# Processing Record 35 of Set 6 | alice springs
# Processing Record 36 of Set 6 | port-gentil
# Processing Record 37 of Set 6 | hasaki
# Processing Record 38 of Set 6 | upington
# Processing Record 39 of Set 6 | kuandian
# Processing Record 40 of Set 6 | upernavik
# Processing Record 41 of Set 6 | viligili
# 'coord'
# Processing Record 42 of Set 6 | barentsburg
# 'coord'
# Processing Record 43 of Set 6 | neosho
# Processing Record 44 of Set 6 | naples
# Processing Record 45 of Set 6 | parczew
# Processing Record 46 of Set 6 | kattivakkam
# Processing Record 47 of Set 6 | oni
# Processing Record 48 of Set 6 | caravelas
# Processing Record 49 of Set 6 | beidao
# Processing Record 50 of Set 6 | grindavik
# Processing Record 1 of Set 7 | baoqing
# Processing Record 2 of Set 7 | lasa
# Processing Record 3 of Set 7 | sambava
# Processing Record 4 of Set 7 | svetlaya
# Processing Record 5 of Set 7 | xuanhua
# Processing Record 6 of Set 7 | ekhabi
# Processing Record 7 of Set 7 | rio grande
# Processing Record 8 of Set 7 | roseburg
# Processing Record 9 of Set 7 | itaquyry
# Processing Record 10 of Set 7 | port lincoln
# Processing Record 11 of Set 7 | constitucion
# Processing Record 12 of Set 7 | samusu
# 'coord'
# Processing Record 13 of Set 7 | tsihombe
# 'coord'
# Processing Record 14 of Set 7 | ribeira grande
# Processing Record 15 of Set 7 | monroe
# Processing Record 16 of Set 7 | imola
# Processing Record 17 of Set 7 | fortuna
# Processing Record 18 of Set 7 | chuy
# Processing Record 19 of Set 7 | elat
# Processing Record 20 of Set 7 | tasiilaq
# Processing Record 21 of Set 7 | miri
# Processing Record 22 of Set 7 | kondinskoye
# Processing Record 23 of Set 7 | macaboboni
# 'coord'
# Processing Record 24 of Set 7 | alofi
# Processing Record 25 of Set 7 | madimba
# Processing Record 26 of Set 7 | hobyo
# Processing Record 27 of Set 7 | marathon
# Processing Record 28 of Set 7 | adrar
# Processing Record 29 of Set 7 | guerrero negro
# Processing Record 30 of Set 7 | fort wellington
# Processing Record 31 of Set 7 | harper
# Processing Record 32 of Set 7 | antofagasta
# Processing Record 33 of Set 7 | la rioja
# Processing Record 34 of Set 7 | new baltimore
# Processing Record 35 of Set 7 | cayenne
# Processing Record 36 of Set 7 | eldikan
# 'coord'
# Processing Record 37 of Set 7 | ukiah
# Processing Record 38 of Set 7 | dalbandin
# Processing Record 39 of Set 7 | apud
# Processing Record 40 of Set 7 | geraldton
# Processing Record 41 of Set 7 | bambous virieux
# Processing Record 42 of Set 7 | bara
# Processing Record 43 of Set 7 | ust-kamchatsk
# 'coord'
# Processing Record 44 of Set 7 | meyungs
# 'coord'
# Processing Record 45 of Set 7 | fairbanks
# Processing Record 46 of Set 7 | jacareacanga
# Processing Record 47 of Set 7 | pringsewu
# Processing Record 48 of Set 7 | atar
# Processing Record 49 of Set 7 | mahebourg
# Processing Record 50 of Set 7 | ayan
# Processing Record 1 of Set 8 | muroto
# Processing Record 2 of Set 8 | parker
# Processing Record 3 of Set 8 | itoman
# Processing Record 4 of Set 8 | lompoc
# Processing Record 5 of Set 8 | nawa
# Processing Record 6 of Set 8 | mariakani
# Processing Record 7 of Set 8 | gualaquiza
# Processing Record 8 of Set 8 | beloha
# Processing Record 9 of Set 8 | huejuquilla el alto
# Processing Record 10 of Set 8 | kaifeng
# Processing Record 11 of Set 8 | bud
# Processing Record 12 of Set 8 | necochea
# Processing Record 13 of Set 8 | teonthar
# Processing Record 14 of Set 8 | pacific grove
# Processing Record 15 of Set 8 | iquitos
# Processing Record 16 of Set 8 | hirara
# Processing Record 17 of Set 8 | san patricio
# Processing Record 18 of Set 8 | jerome
# Processing Record 19 of Set 8 | koslan
# Processing Record 20 of Set 8 | faya
# Processing Record 21 of Set 8 | amalapuram
# Processing Record 22 of Set 8 | rivers
# Processing Record 23 of Set 8 | taoudenni
# Processing Record 24 of Set 8 | timra
# Processing Record 25 of Set 8 | clyde river
# Processing Record 26 of Set 8 | grand river south east
# 'coord'
# Processing Record 27 of Set 8 | visnes
# Processing Record 28 of Set 8 | abong mbang
# Processing Record 29 of Set 8 | huron
# Processing Record 30 of Set 8 | samalaeulu
# 'coord'
# Processing Record 31 of Set 8 | san vicente
# Processing Record 32 of Set 8 | katangli
# Processing Record 33 of Set 8 | kruisfontein
# Processing Record 34 of Set 8 | drayton valley
# Processing Record 35 of Set 8 | mana
# Processing Record 36 of Set 8 | cumaribo
# 'coord'
# Processing Record 37 of Set 8 | bend
# Processing Record 38 of Set 8 | xiaoyi
# Processing Record 39 of Set 8 | richards bay
# Processing Record 40 of Set 8 | barranca
# Processing Record 41 of Set 8 | pitelino
# Processing Record 42 of Set 8 | ternate
# Processing Record 43 of Set 8 | lalomanu
# 'coord'
# Processing Record 44 of Set 8 | hamilton
# Processing Record 45 of Set 8 | bandarbeyla
# Processing Record 46 of Set 8 | inta
# Processing Record 47 of Set 8 | nago
# Processing Record 48 of Set 8 | west lafayette
# Processing Record 49 of Set 8 | ailigandi
# Processing Record 50 of Set 8 | talabaan
# Processing Record 1 of Set 9 | alice town
# Processing Record 2 of Set 9 | bonavista
# Processing Record 3 of Set 9 | santa barbara
# Processing Record 4 of Set 9 | ancud
# Processing Record 5 of Set 9 | nicolas bravo
# Processing Record 6 of Set 9 | chumikan
# Processing Record 7 of Set 9 | barber
# Processing Record 8 of Set 9 | ust-maya
# Processing Record 9 of Set 9 | cabo san lucas
# Processing Record 10 of Set 9 | banepa
# Processing Record 11 of Set 9 | burica
# 'coord'
# Processing Record 12 of Set 9 | hof
# Processing Record 13 of Set 9 | pemangkat
# Processing Record 14 of Set 9 | verkhnevilyuysk
# Processing Record 15 of Set 9 | yamada
# Processing Record 16 of Set 9 | jumla
# Processing Record 17 of Set 9 | road town
# Processing Record 18 of Set 9 | karad
# Processing Record 19 of Set 9 | athni
# Processing Record 20 of Set 9 | jaca
# Processing Record 21 of Set 9 | svetlogorsk
# Processing Record 22 of Set 9 | chokurdakh
# Processing Record 23 of Set 9 | hofn
# Processing Record 24 of Set 9 | te anau
# Processing Record 25 of Set 9 | freeport
# Processing Record 26 of Set 9 | havelock
# Processing Record 27 of Set 9 | dubbo
# Processing Record 28 of Set 9 | yatou
# Processing Record 29 of Set 9 | grootfontein
# Processing Record 30 of Set 9 | sobolevo
# Processing Record 31 of Set 9 | ambilobe
# Processing Record 32 of Set 9 | sataua
# 'coord'
# Processing Record 33 of Set 9 | grand-lahou
# Processing Record 34 of Set 9 | cidreira
# Processing Record 35 of Set 9 | berlevag
# Processing Record 36 of Set 9 | sumenep
# Processing Record 37 of Set 9 | kieta
# Processing Record 38 of Set 9 | ossora
# Processing Record 39 of Set 9 | assiniboia
# Processing Record 40 of Set 9 | kaeo
# Processing Record 41 of Set 9 | hargeysa
# Processing Record 42 of Set 9 | lahij
# Processing Record 43 of Set 9 | bengkulu
# Processing Record 44 of Set 9 | eirunepe
# Processing Record 45 of Set 9 | vestmannaeyjar
# Processing Record 46 of Set 9 | viedma
# Processing Record 47 of Set 9 | cap malheureux
# Processing Record 48 of Set 9 | karratha
# Processing Record 49 of Set 9 | honningsvag
# Processing Record 50 of Set 9 | borama
# 'coord'
# Processing Record 1 of Set 10 | polyarnyy
# Processing Record 2 of Set 10 | nhulunbuy
# Processing Record 3 of Set 10 | abu dhabi
# Processing Record 4 of Set 10 | wajir
# Processing Record 5 of Set 10 | pangnirtung
# Processing Record 6 of Set 10 | kita
# Processing Record 7 of Set 10 | pochutla
# Processing Record 8 of Set 10 | manhattan
# Processing Record 9 of Set 10 | shkotovo-26
# 'coord'
# Processing Record 10 of Set 10 | mombetsu
# Processing Record 11 of Set 10 | cobija
# Processing Record 12 of Set 10 | fort saint john
# 'coord'
# Processing Record 13 of Set 10 | rincon
# Processing Record 14 of Set 10 | opotiki
# Processing Record 15 of Set 10 | lensk
# Processing Record 16 of Set 10 | chaman
# Processing Record 17 of Set 10 | khani
# Processing Record 18 of Set 10 | padina
# Processing Record 19 of Set 10 | taldan
# Processing Record 20 of Set 10 | kodino
# Processing Record 21 of Set 10 | sinnamary
# Processing Record 22 of Set 10 | kedrovyy
# Processing Record 23 of Set 10 | obigarm
# Processing Record 24 of Set 10 | urdoma
# Processing Record 25 of Set 10 | hilton head island
# Processing Record 26 of Set 10 | tiksi
# Processing Record 27 of Set 10 | mahibadhoo
# Processing Record 28 of Set 10 | mehamn
# Processing Record 29 of Set 10 | ales
# Processing Record 30 of Set 10 | yulara
# Processing Record 31 of Set 10 | shimoda
# Processing Record 32 of Set 10 | reconquista
# Processing Record 33 of Set 10 | sept-iles
# Processing Record 34 of Set 10 | san cristobal
# Processing Record 35 of Set 10 | vanimo
# Processing Record 36 of Set 10 | martapura
# Processing Record 37 of Set 10 | sur
# Processing Record 38 of Set 10 | bilibino
# Processing Record 39 of Set 10 | chagda
# 'coord'
# Processing Record 40 of Set 10 | abu samrah
# Processing Record 41 of Set 10 | vredefort
# Processing Record 42 of Set 10 | boysun
# Processing Record 43 of Set 10 | henties bay
# Processing Record 44 of Set 10 | nizhneyansk
# 'coord'
# Processing Record 45 of Set 10 | sangin
# Processing Record 46 of Set 10 | mapiripan
# Processing Record 47 of Set 10 | kalabo
# Processing Record 48 of Set 10 | talaya
# Processing Record 49 of Set 10 | san francisco
# Processing Record 50 of Set 10 | kavaratti
# Processing Record 1 of Set 11 | kenai
# Processing Record 2 of Set 11 | loandjili
# Processing Record 3 of Set 11 | ostrovnoy
# Processing Record 4 of Set 11 | mergui
# 'coord'
# Processing Record 5 of Set 11 | nortelandia
# Processing Record 6 of Set 11 | homer
# Processing Record 7 of Set 11 | meulaboh
# Processing Record 8 of Set 11 | anito
# Processing Record 9 of Set 11 | sovetskaya gavan
# Processing Record 10 of Set 11 | morros
# Processing Record 11 of Set 11 | dudinka
# Processing Record 12 of Set 11 | warqla
# 'coord'
# Processing Record 13 of Set 11 | sijunjung
# Processing Record 14 of Set 11 | akyab
# Processing Record 15 of Set 11 | mackenzie
# Processing Record 16 of Set 11 | santa rosalia
# Processing Record 17 of Set 11 | luderitz
# Processing Record 18 of Set 11 | kashi
# Processing Record 19 of Set 11 | pindiga
# Processing Record 20 of Set 11 | pontefract
# Processing Record 21 of Set 11 | sinegorye
# Processing Record 22 of Set 11 | garissa
# Processing Record 23 of Set 11 | taybad
# Processing Record 24 of Set 11 | guadalupe
# Processing Record 25 of Set 11 | olafsvik
# Processing Record 26 of Set 11 | puerto padre
# Processing Record 27 of Set 11 | ewa beach
# Processing Record 28 of Set 11 | tura
# Processing Record 29 of Set 11 | port hawkesbury
# Processing Record 30 of Set 11 | cheremshan
# Processing Record 31 of Set 11 | berberati
# Processing Record 32 of Set 11 | dunedin
# Processing Record 33 of Set 11 | dalmatovo
# Processing Record 34 of Set 11 | ahuimanu
# Processing Record 35 of Set 11 | takefu
# Processing Record 36 of Set 11 | foundiougne
# Processing Record 37 of Set 11 | sarkand
# Processing Record 38 of Set 11 | bargal
# 'coord'
# Processing Record 39 of Set 11 | faro
# Processing Record 40 of Set 11 | kilindoni
# Processing Record 41 of Set 11 | andra
# Processing Record 42 of Set 11 | husavik
# Processing Record 43 of Set 11 | tautira
# Processing Record 44 of Set 11 | lovozero
# Processing Record 45 of Set 11 | marrakesh
# Processing Record 46 of Set 11 | ibirama
# Processing Record 47 of Set 11 | port hardy
# Processing Record 48 of Set 11 | ulaangom
# Processing Record 49 of Set 11 | la maddalena
# Processing Record 50 of Set 11 | kapuskasing
# Processing Record 1 of Set 12 | malindi
# Processing Record 2 of Set 12 | hay river
# Processing Record 3 of Set 12 | giyani
# Processing Record 4 of Set 12 | adwa
# Processing Record 5 of Set 12 | minot
# Processing Record 6 of Set 12 | ust-kuyga
# Processing Record 7 of Set 12 | chernyshevskiy
# Processing Record 8 of Set 12 | bandar penggaram
# 'coord'
# Processing Record 9 of Set 12 | guapiacu
# Processing Record 10 of Set 12 | deputatskiy
# Processing Record 11 of Set 12 | caronport
# Processing Record 12 of Set 12 | rudsar
# Processing Record 13 of Set 12 | prince rupert
# Processing Record 14 of Set 12 | canton
# Processing Record 15 of Set 12 | kortenaken
# Processing Record 16 of Set 12 | bajil
# Processing Record 17 of Set 12 | luebo
# Processing Record 18 of Set 12 | diamantino
# Processing Record 19 of Set 12 | besikduzu
# Processing Record 20 of Set 12 | palabuhanratu
# 'coord'
# Processing Record 21 of Set 12 | bull savanna
# Processing Record 22 of Set 12 | coahuayana
# Processing Record 23 of Set 12 | noeux-les-mines
# Processing Record 24 of Set 12 | bayangol
# Processing Record 25 of Set 12 | ziarat
# Processing Record 26 of Set 12 | aykhal
# Processing Record 27 of Set 12 | kamenskoye
# 'coord'
# Processing Record 28 of Set 12 | gobabis
# Processing Record 29 of Set 12 | puerto leguizamo
# Processing Record 30 of Set 12 | jalu
# Processing Record 31 of Set 12 | soyo
# Processing Record 32 of Set 12 | clovis
# Processing Record 33 of Set 12 | valdivia
# Processing Record 34 of Set 12 | ratnagiri
# Processing Record 35 of Set 12 | port jervis
# Processing Record 36 of Set 12 | strezhevoy
# Processing Record 37 of Set 12 | irbil
# Processing Record 38 of Set 12 | coquimbo
# Processing Record 39 of Set 12 | talcahuano
# Processing Record 40 of Set 12 | flagstaff
# Processing Record 41 of Set 12 | ulverstone
# Processing Record 42 of Set 12 | zhangye
# Processing Record 43 of Set 12 | batagay-alyta
# Processing Record 44 of Set 12 | nishihara
# Processing Record 45 of Set 12 | griffith
# Processing Record 46 of Set 12 | ayagoz
# Processing Record 47 of Set 12 | podosinovets
# Processing Record 48 of Set 12 | sarkikaraagac
# Processing Record 49 of Set 12 | zhigansk
# Processing Record 50 of Set 12 | arlit
# Processing Record 1 of Set 13 | konstantinovka
# Processing Record 2 of Set 13 | sioux lookout
# Processing Record 3 of Set 13 | viking
# Processing Record 4 of Set 13 | kamenka
# Processing Record 5 of Set 13 | dongli
# Processing Record 6 of Set 13 | bristol
# Processing Record 7 of Set 13 | moerai
# Processing Record 8 of Set 13 | caledon
# Processing Record 9 of Set 13 | la palma
# Processing Record 10 of Set 13 | manado
# Processing Record 11 of Set 13 | seguin
# Processing Record 12 of Set 13 | alcantara
# Processing Record 13 of Set 13 | nanakuli
# Processing Record 14 of Set 13 | sangar
# Processing Record 15 of Set 13 | ballyhaunis
# Processing Record 16 of Set 13 | den helder
# Processing Record 17 of Set 13 | bokspits
# 'coord'
# Processing Record 18 of Set 13 | hambantota
# Processing Record 19 of Set 13 | olga
# Processing Record 20 of Set 13 | gornyy
# Processing Record 21 of Set 13 | balabac
# Processing Record 22 of Set 13 | kargasok
# Processing Record 23 of Set 13 | akhmeta
# Processing Record 24 of Set 13 | jijiga
# Processing Record 25 of Set 13 | zabid
# Processing Record 26 of Set 13 | the valley
# Processing Record 27 of Set 13 | kisangani
# Processing Record 28 of Set 13 | turayf
# Processing Record 29 of Set 13 | zeya
# Processing Record 30 of Set 13 | san jeronimo
# Processing Record 31 of Set 13 | kousseri
# Processing Record 32 of Set 13 | ashland
# Processing Record 33 of Set 13 | traipu
# Processing Record 34 of Set 13 | anisoc
# Processing Record 35 of Set 13 | drymen
# Processing Record 36 of Set 13 | blantyre
# Processing Record 37 of Set 13 | floriano
# Processing Record 38 of Set 13 | ye
# 'coord'
# Processing Record 39 of Set 13 | mkushi
# Processing Record 40 of Set 13 | shingu
# Processing Record 41 of Set 13 | northam
# Processing Record 42 of Set 13 | kondoa
# Processing Record 43 of Set 13 | ouadda
# Processing Record 44 of Set 13 | jiana
# Processing Record 45 of Set 13 | pattani
# Processing Record 46 of Set 13 | lakatoro
# Processing Record 47 of Set 13 | salina
# Processing Record 48 of Set 13 | onega
# Processing Record 49 of Set 13 | deer lake
# Processing Record 50 of Set 13 | joshimath
# Processing Record 1 of Set 14 | mancio lima
# Processing Record 2 of Set 14 | fredericton
# Processing Record 3 of Set 14 | general bravo
# Processing Record 4 of Set 14 | at-bashi
# Processing Record 5 of Set 14 | monte cristi
# 'coord'
# Processing Record 6 of Set 14 | kollo
# Processing Record 7 of Set 14 | la ronge
# Processing Record 8 of Set 14 | kamaishi
# Processing Record 9 of Set 14 | lexington
# Processing Record 10 of Set 14 | north bend
# Processing Record 11 of Set 14 | dhidhdhoo
# Processing Record 12 of Set 14 | zabol
# Processing Record 13 of Set 14 | ndouci
# 'coord'
# Processing Record 14 of Set 14 | neuquen
# Processing Record 15 of Set 14 | aflu
# 'coord'
# Processing Record 16 of Set 14 | denpasar
# Processing Record 17 of Set 14 | jintur
# Processing Record 18 of Set 14 | ambon
# Processing Record 19 of Set 14 | dakoro
# Processing Record 20 of Set 14 | myanaung
# Processing Record 21 of Set 14 | lumphat
# Processing Record 22 of Set 14 | tambau
# Processing Record 23 of Set 14 | mutsamudu
# 'coord'
# Processing Record 24 of Set 14 | bandarban
# Processing Record 25 of Set 14 | kuching
# Processing Record 26 of Set 14 | patiya
# Processing Record 27 of Set 14 | makaha
# Processing Record 28 of Set 14 | yarega
# Processing Record 29 of Set 14 | lom sak
# Processing Record 30 of Set 14 | omboue
# Processing Record 31 of Set 14 | plettenberg bay
# Processing Record 32 of Set 14 | waingapu
# Processing Record 33 of Set 14 | minamata
# Processing Record 34 of Set 14 | ijaki
# 'coord'
# Processing Record 35 of Set 14 | ishigaki
# Processing Record 36 of Set 14 | kutum
# Processing Record 37 of Set 14 | maracaibo
# Processing Record 38 of Set 14 | port augusta
# Processing Record 39 of Set 14 | matara
# Processing Record 40 of Set 14 | marsa matruh
# Processing Record 41 of Set 14 | banjar
# Processing Record 42 of Set 14 | bay saint louis
# Processing Record 43 of Set 14 | puerto narino
# Processing Record 44 of Set 14 | champerico
# Processing Record 45 of Set 14 | concordia
# Processing Record 46 of Set 14 | placido de castro
# Processing Record 47 of Set 14 | tyup
# Processing Record 48 of Set 14 | marzuq
# Processing Record 49 of Set 14 | grafton
# Processing Record 50 of Set 14 | takoradi
# Processing Record 1 of Set 15 | tazovskiy
# Processing Record 2 of Set 15 | gainesville
# Processing Record 3 of Set 15 | hirado
# Processing Record 4 of Set 15 | bumba
# Processing Record 5 of Set 15 | dumai
# Processing Record 6 of Set 15 | bonthe
# Processing Record 7 of Set 15 | boyolangu
# Processing Record 8 of Set 15 | asau
# Processing Record 9 of Set 15 | daud khel
# Processing Record 10 of Set 15 | fare
# Processing Record 11 of Set 15 | lakes entrance
# Processing Record 12 of Set 15 | abha
# Processing Record 13 of Set 15 | rimbey
# Processing Record 14 of Set 15 | daru
# Processing Record 15 of Set 15 | moree
# Processing Record 16 of Set 15 | kashary
# Processing Record 17 of Set 15 | sakakah
# Processing Record 18 of Set 15 | key west
# Processing Record 19 of Set 15 | maceio
# Processing Record 20 of Set 15 | aswan
# Processing Record 21 of Set 15 | melnikovo
# Processing Record 22 of Set 15 | barawe
# 'coord'
# Processing Record 23 of Set 15 | bo rai
# Processing Record 24 of Set 15 | tambopata
# Processing Record 25 of Set 15 | itambe
# Processing Record 26 of Set 15 | tanout
# Processing Record 27 of Set 15 | thunder bay
# Processing Record 28 of Set 15 | emba
# Processing Record 29 of Set 15 | las guacamayas
# Processing Record 30 of Set 15 | sisimiut
# Processing Record 31 of Set 15 | ios
# Processing Record 32 of Set 15 | dukat
# Processing Record 33 of Set 15 | ji-parana
# 'coord'
# Processing Record 34 of Set 15 | srandakan
# Processing Record 35 of Set 15 | west wendover
# Processing Record 36 of Set 15 | puerto rico
# Processing Record 37 of Set 15 | melfi
# Processing Record 38 of Set 15 | cap-aux-meules
# Processing Record 39 of Set 15 | paso de los toros
# Processing Record 40 of Set 15 | bogo
# Processing Record 41 of Set 15 | lemesos
# 'coord'
# Processing Record 42 of Set 15 | comodoro rivadavia
# Processing Record 43 of Set 15 | alugan
# Processing Record 44 of Set 15 | mgandu
# Processing Record 45 of Set 15 | severodvinsk
# Processing Record 46 of Set 15 | mareeba
# Processing Record 47 of Set 15 | mahadday weyne
# 'coord'
# Processing Record 48 of Set 15 | betafo
# Processing Record 49 of Set 15 | verkhoyansk
# Processing Record 50 of Set 15 | santa rosa
# Processing Record 1 of Set 16 | la romana
# Processing Record 2 of Set 16 | tiznit
# Processing Record 3 of Set 16 | pekin
# Processing Record 4 of Set 16 | egvekinot
# Processing Record 5 of Set 16 | pauini
# Processing Record 6 of Set 16 | rio gallegos
# Processing Record 7 of Set 16 | araguacu
# Processing Record 8 of Set 16 | hanstholm
# Processing Record 9 of Set 16 | hagi
# Processing Record 10 of Set 16 | hornepayne
# Processing Record 11 of Set 16 | hinwil
# Processing Record 12 of Set 16 | chernyshevsk
# Processing Record 13 of Set 16 | fasa
# Processing Record 14 of Set 16 | umm lajj
# Processing Record 15 of Set 16 | shelburne
# Processing Record 16 of Set 16 | astana
# Processing Record 17 of Set 16 | zhireken
# Processing Record 18 of Set 16 | banda aceh
# Processing Record 19 of Set 16 | uthal
# Processing Record 20 of Set 16 | arica
# Processing Record 21 of Set 16 | samarai
# Processing Record 22 of Set 16 | urengoy
# Processing Record 23 of Set 16 | darnah
# Processing Record 24 of Set 16 | prado
# Processing Record 25 of Set 16 | pandan
# Processing Record 26 of Set 16 | kandrian
# Processing Record 27 of Set 16 | flinders
# Processing Record 28 of Set 16 | moscow
# Processing Record 29 of Set 16 | tezu
# Processing Record 30 of Set 16 | marystown
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 720

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         San Jose  37.3394 -121.8950     50.47        64           0
# 1    Saint Austell  50.3383   -4.7658     47.01        87          99
# 2      Provideniya  64.3833 -173.3000     32.36       100         100
# 3           Barrow  71.2906 -156.7887     10.42        79         100
# 4         Altamira  -3.2033  -52.2064     71.58        98          96
# 5     Beringovskiy  63.0500  179.3167     30.47        99         100
# 6  Arraial Do Cabo -22.9661  -42.0278     73.09        90          80
# 7        Esperance -33.8667  121.9000     78.12        38         100
# 8            Naron  43.5167   -8.1528     54.45        83         100
# 9         Saldanha -33.0117   17.9442     62.65        95          42
#
#    Wind Speed Country Current Description
# 0        8.05      US           clear sky
# 1        9.22      GB     overcast clouds
# 2        7.00      RU                snow
# 3       14.97      US          light snow
# 4        0.74      BR       moderate rain
# 5        2.39      RU                snow
# 6       21.45      BR       broken clouds
# 7       13.20      AU          light rain
# 8        8.21      ES     overcast clouds
# 9        5.06      ZA    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
new_city_df = city_data_df[new_column_order]

# Display sample data
new_city_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         San Jose      US  37.3394 -121.8950     50.47        64           0
# 1    Saint Austell      GB  50.3383   -4.7658     47.01        87          99
# 2      Provideniya      RU  64.3833 -173.3000     32.36       100         100
# 3           Barrow      US  71.2906 -156.7887     10.42        79         100
# 4         Altamira      BR  -3.2033  -52.2064     71.58        98          96
# 5     Beringovskiy      RU  63.0500  179.3167     30.47        99         100
# 6  Arraial Do Cabo      BR -22.9661  -42.0278     73.09        90          80
# 7        Esperance      AU -33.8667  121.9000     78.12        38         100
# 8            Naron      ES  43.5167   -8.1528     54.45        83         100
# 9         Saldanha      ZA -33.0117   17.9442     62.65        95          42
#
#    Wind Speed Current Description
# 0        8.05           clear sky
# 1        9.22     overcast clouds
# 2        7.00                snow
# 3       14.97          light snow
# 4        0.74       moderate rain
# 5        2.39                snow
# 6       21.45       broken clouds
# 7       13.20          light rain
# 8        8.21     overcast clouds
# 9        5.06    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
new_city_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
new_city_df.to_csv(output_data_file, index_label="City_ID")
